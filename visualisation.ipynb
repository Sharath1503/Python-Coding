# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = [3,45,30,23,45]

# %%
plt.plot(y)

# %%
plt.plot(y, 'w,')

# %%
p = [89,78,76,89,76]
i = [90,95,78,70,67]
k = [89,98,78,76,90]
plt.plot(p,'g--', label="Ghouse", marker='o' )
plt.plot(i,'y-', label="Aaquib", marker='o' )
plt.plot(k,'r--', label="Zaid", marker='o' )
plt.legend()

# %%
temp = [35.5,36.6,28,32.3,34.5,37.9,45]
days = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
plt.bar(days, height=temp)

# %%
sports = [11,7,2,10,9]
names = ['Cricket','Basketball','carrom','Volleyball','Football']
colors = ['Blue','Black','Red','Yellow','Green']
print(plt.pie(sports, labels=names, colors=colors))

# %%
# The emotional Journey of Learning Python
# lt.rcParams['font.family'] = 'Segoe UI Emoji' # rcParams is dictionary where we can add extra things
events = ['start', 'Hello\nWorld', 'Datatypes', 'Control flow', 'Data Structures', 'Functions', 'OOPS', 'Data Analysis','Web Dev', 'Project']
weeks = np.arange(len(events))
confidence = [7,10,9,6,4,3,2,5,6,8]

plt.figure(figsize=(12,6))
plt.plot(weeks, confidence, marker='o', linewidth=2, markersize=8, color= 'blue', markerfacecolor='orange')

plt.annotate('Peak of Confidence', xy=(1,9.8), xytext=(1,7), ha='center', arrowprops=dict(facecolor='green', shrink = 0.05, width =4))

# %%
data = [100,239,594,12000,22999,29919,16999,18000]
players = ['sigzil', 'Teft','Zaid','Aaquib','Kamil','Ghouse','Faruk','Naushad']

fig, ax = plt.subplots(figsize=(10,5))
plt.barh(players,data)
plt.show()
